# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
events = pd.read_csv('./out.csv', low_memory=False)
events.head()
# Out:
# /Users/akukettunen/Desktop/ml-course/sample-project/env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (31,35) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          tulos  vapaataival  vapaa  vaara  koordinaatitX  koordinaatitY  \
# 0        Vapaa        False    NaN  False            NaN            NaN
# 1        Vapaa        False    NaN  False            NaN            NaN
# 2        Vapaa        False    NaN  False            NaN            NaN
# 3         Palo        False    NaN  False            NaN            NaN
# 4  Kärkilyönti        False    NaN  False            NaN            NaN
#
#    jokerHat             lyoja  lyojaVieras    vvo  ...       endtime lyonti  \
# 0     False     Topi Korhonen            1  False  ...   3843.149438      1
# 1     False   Ossi Meriläinen            1  False  ...  10104.901373      3
# ...
