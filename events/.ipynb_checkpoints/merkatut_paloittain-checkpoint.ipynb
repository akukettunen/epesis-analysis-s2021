# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
csv_name = 'events_2021_nsu'
events = pd.read_csv('./{}.csv'.format(csv_name), low_memory=False)
events
# Out:
#              tulos  vapaataival  vapaa  vaara  koordinaatitX  koordinaatitY  \
# 0            Vapaa        False  False  False         0.4917         0.9241
# 1      Kärkilyönti        False  False  False         0.2326         0.5000
# 2      Kärkilyönti        False  False  False         0.5028         0.9472
# 3      Kärkilyönti        False  False  False         0.2097         0.4415
# 4      Kärkilyönti        False  False  False         0.5044         0.5411
# ...            ...          ...    ...    ...            ...            ...
# 58862  Kärkilyönti        False  False  False         0.3688         0.7052
# 58863        Vapaa        False  False  False         0.5373         0.6235
# 58864         Palo        False  False  False         0.5503         0.8964
# 58865  Kärkilyönti        False  False  False         0.5031         0.8640
# 58866        Vapaa        False  False   True            NaN            NaN
#
#        jokerHat              lyoja  lyojaVieras    vvo  ...      endtime  \
# 0         False   Jutta Myllyniemi            9  False  ...  1809.938208
# 1          True        Pinja Kesti            9  False  ...  4011.474114
# 2         False        Emma Körkkö            7  False  ...  7616.786782
# 3         False       Ella Korpela            9  False  ...  1489.647789
# 4         False        Emma Körkkö            9  False  ...  1584.565860
# ...         ...                ...          ...    ...  ...          ...
# 58862     False      Tiia Peltonen            4  False  ...  8549.753726
# 58863     False         Henna Juka            6  False  ...  5129.854798
# 58864     False  Eeva Mäki-Maukola            2  False  ...  3632.012226
# 58865     False     Emilia Itävalo            1  False  ...  3256.992469
# 58866      True        Siri Eskola            5  False  ...  5785.352695
#
#       lyonti karkaaminen          tyyppi  lyoty      expiry  \
# 0          1       False           nappi   True  1654009200
# 1          3       False  pystari/viisto   True  1654009200
# 2          1       False             muu   True  1654009200
# 3          2       False      vaakamaila   True  1654009200
# 4          2       False      vaakamaila   True  1654009200
# ...      ...         ...             ...    ...         ...
# 58862      1       False      vaakamaila   True  1663930800
# 58863      2       False  pystari/viisto   True  1663930800
# 58864      1       False           nappi   True  1663930800
# 58865      3       False           nappi   True  1663930800
# 58866      1       False             NaN  False  1663930800
#
#                   pesat0           pesat1             pesat2  \
# 0       Jutta Myllyniemi   Viivi Partanen        Siri Eskola
# 1            Pinja Kesti              NaN                NaN
# 2            Emma Körkkö  Venla Karttunen       Ella Korpela
# 3           Ella Korpela              NaN                NaN
# 4            Emma Körkkö  Venla Karttunen  Eeva Mäki-Maukola
# ...                  ...              ...                ...
# 58862      Tiia Peltonen              NaN                NaN
# 58863         Henna Juka              NaN                NaN
# 58864  Eeva Mäki-Maukola     Ella Korpela                NaN
# 58865     Emilia Itävalo       Henna Juka                NaN
# 58866        Siri Eskola      Emma Körkkö   Jutta Myllyniemi
#
#                   pesat3
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4           Ella Korpela
# ...                  ...
# 58862                NaN
# 58863                NaN
# 58864                NaN
# 58865                NaN
# 58866  Eeva Mäki-Maukola
#
# [58867 rows x 42 columns]

# %%
events.columns
# Out:
# Index(['tulos', 'vapaataival', 'vapaa', 'vaara', 'koordinaatitX',
#        'koordinaatitY', 'jokerHat', 'lyoja', 'lyojaVieras', 'vvo', 'changes0',
#        'changes1', 'changes2', 'changes3', 'lukkari', 'date', 'palot',
#        'karpanen', 'lyojaKoti', 'streamUrl', 'tilanne', 'merkattuLaiton', 'up',
#        'gameId', 'sp', 'karki', 'sisalla', 'phaseDone', 'eventId', 'kl',
#        'starttime', 'mitataanAika', 'endtime', 'lyonti', 'karkaaminen',
#        'tyyppi', 'lyoty', 'expiry', 'pesat0', 'pesat1', 'pesat2', 'pesat3'],
#       dtype='object')

# %% [markdown]
# # Datan filtteröinti

# %%
ev = events[['tulos', 'lyonti', 'tilanne', 'sp', 'palot', 'tyyppi']]

ev = ev[ev['tyyppi'] != 'kopinnosto']

ajot = ev[ev['tilanne'].isin(['Ajo'])]
kakkoset = ev[ev['tilanne'].isin(['1-2'])]
ykkoset = ev[ev['tilanne'].isin(['1', 1])]

merkatut_ajot = ajot[ajot['tulos'] != 'Vapaa']
merkatut_kakkoset = kakkoset[kakkoset['tulos'] != 'Vapaa']
merkatut_ykkoset = ykkoset[ykkoset['tulos'] != 'Vapaa']

# %% [markdown]
# # Osuudet lyönneittäin

# %%
ykkostilanne = merkatut_ykkoset.groupby(by='lyonti').count().tulos
kakkostilanne = merkatut_kakkoset.groupby(by='lyonti').count().tulos
kolmostilanne = merkatut_ajot.groupby(by='lyonti').count().tulos

maara1 = ykkostilanne.sum()
maara2 = kakkostilanne.sum()
maara3 = kolmostilanne.sum()

first_hits = pd.Series([
    ykkostilanne[1] / maara1 * 100, 
    kakkostilanne[1] / maara2 * 100, 
    kolmostilanne[1] / maara3 * 100
])
second_hits = pd.Series([
    ykkostilanne[2] / maara1 * 100, 
    kakkostilanne[2] / maara2 * 100, 
    kolmostilanne[2] / maara3 * 100
])
third_hits = pd.Series([
    ykkostilanne[3] / maara1 * 100, 
    kakkostilanne[3] / maara2 * 100, 
    kolmostilanne[3] / maara3 * 100
])

df = pd.DataFrame(
    np.array([first_hits, second_hits, third_hits])
    , columns=['1-tilanne', '2-tilanne', '3-tilanne'], index=[1, 2, 3])

[ykkostilanne.sum(), kakkostilanne.sum(), kolmostilanne.sum()]
# Out:
# [6773, 4343, 3449]

# %% [markdown]
# # Piirretään barit

# %%
# fig, axs = plt.subplots(1, 3, figsize = (10, 10))
fig, ax = plt.subplots(figsize = (10, 10))

lyontien_nimet = ['1. lyonti', '2. lyonti', '3. lyonti']

ind = np.arange(3)

p1 = plt.bar(ind, first_hits, width=0.8, label="1. lyonti")
p3 = plt.bar(ind, third_hits, width=0.8, label="3. lyonti", bottom=first_hits + second_hits)
p2 = plt.bar(ind, second_hits, width=0.8, label="2. lyonti", bottom=first_hits)

plt.legend()

ax.set_ylabel('Osuus (%)', fontweight ='bold', fontsize = 15)
ax.set_title('Merkatun lyönnin numero tilanteittain', fontweight ='bold', fontsize = 15)
plt.xticks(ind, ('1-tilanne', '1-2-tilanne', 'Ajo'))

plt.show()

fig.savefig('./merkatut_lyonneittain_{}.png'.format(csv_name))
