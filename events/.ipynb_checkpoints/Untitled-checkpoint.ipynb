# %% [markdown]
# # Lyöntityyppien osuus tilanteittain ja kunkin onnistumisprosentti

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
season = 2021
league = 'msu'
base = ['1']

events = pd.read_csv('./events_{}_{}.csv'.format(season, league), low_memory=False)
events['tilanne']
# Out:
# 0        Ajo
# 1        1-3
# 2        1-2
# 3          1
# 4          0
#         ...
# 77045      1
# 77046    Ajo
# 77047      1
# 77048      1
# 77049    0-2
# Name: tilanne, Length: 77050, dtype: object

# %%
events_by_base = events[events['tilanne'].isin(base)]
by_type = events_by_base['tyyppi'].value_counts()
count = len(events_by_base)

final = pd.DataFrame(columns=['tyyppi', '%', 'kärkipalo', 'haava', 'kärkilyönti'])

for a in by_type.index:
    all_type = events_by_base = events[events['tyyppi'] == a]
    all_len = len(all_type)
    type_counts = all_type['tulos'].value_counts()
    type_counts = type_counts / all_len
    # print(type_counts)
    trio = type_counts['Palo'] + type_counts['Haava'] + type_counts['Kärkilyönti']
    final = final.append({
        'tyyppi': a,
        '%': round(by_type[a] / count, 2),
        'kärkipalo': round(type_counts['Palo'] / trio, 2),
        'haava': round(type_counts['Haava'] / trio, 2),
        'kärkilyönti': round(type_counts['Kärkilyönti'] / trio, 2),
    }, ignore_index=True)

# %%
final
# Out:
#            tyyppi     %  kärkipalo  haava  kärkilyönti
# 0      vaakamaila  0.35       0.30   0.17         0.53
# 1           nappi  0.17       0.32   0.01         0.67
# 2  pystari/viisto  0.14       0.15   0.26         0.59
# 3           koppi  0.09       0.06   0.86         0.08
# 4          pomppu  0.07       0.22   0.00         0.78
# 5          kumura  0.04       0.21   0.10         0.69
# 6           varsi  0.01       0.34   0.01         0.66
# 7         pussari  0.01       0.44   0.00         0.55
# 8             muu  0.00       0.37   0.02         0.62

# %%
# Data to plot
labels = ['vaakamaila', 'nappi', 'pystari/viisto', 'koppi', 'pomppu', 'kumura', 'varsi', 'pussari', 'muu']
sizes = final['%']
labels_gender = [
    'kärkilyönti', 'kärkipalo', 'haava',
    'kärkilyönti', 'kärkipalo', 'haava',
    'kärkilyönti', 'kärkipalo', 'haava',
    'kärkilyönti', 'kärkipalo', 'haava',
    'kärkilyönti', 'kärkipalo', 'haava',
    'kärkilyönti', 'kärkipalo', 'haava',
    'kärkilyönti', 'kärkipalo', 'haava',
    'kärkilyönti', 'kärkipalo', 'haava',
    'kärkilyönti', 'kärkipalo', 'haava'
]
sizes_gender = [315,189,125,212,270,145,190,90]
colors = ['#ff6666', '#ffcc99', '#99ff99', '#66b3ff']
colors_gender = ['#c2c2f0','#ffb3e6', '#c2c2f0','#ffb3e6', '#c2c2f0','#ffb3e6', '#c2c2f0','#ffb3e6']
 
# Plot
plt.pie(sizes, labels=labels, colors=colors, startangle=90,frame=True)
plt.pie(sizes_gender,colors=colors_gender,radius=0.75,startangle=90)
centre_circle = plt.Circle((0,0),0.5,color='black', fc='white',linewidth=0)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
 
plt.axis('equal')
plt.tight_layout()
plt.show()
