# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
csv_name = 'runs_msu_2021'
runs = pd.read_csv('./{}.csv'.format(csv_name), low_memory=False)
runs.head()
# Out:
#      id  base     lahto      aika  gameId           eventId    firsttime  \
# 0  1625   1.0  0.199999  4.099991     439  1p8x82bocpchfo1k  4117.952336
# 1  1626   1.0  0.379997  4.839990     439  jokl147gsije75fh  4188.429769
# 2  1627   1.0  0.339999  4.479999     439  r2v7i5ooiihflxvt  4428.599841
# 3  1628   1.0  0.299999  4.239999     439  f5jp93i62r09rkdt  2162.180716
# 4  1629   2.0  0.380000  4.580000     439  viedm1arf1gta4x1  3501.398199
#
#          lukkari  opponent  team          runner  \
# 0   Jani Lassila      1011  1011  Antti Korhonen
# 1   Jani Lassila      1011  1011    Jani Lassila
# 2  Perttu Ruuska      1002  1002     Jere Saukko
# 3  Perttu Ruuska      1002  1002   Teemu Isoketo
# 4   Jani Lassila      1011  1011    Jani Lassila
#
#                                            streamUrl             run_date  \
# 0  https://dpe7aw9wpk40m.cloudfront.net/3e55bb1e-...  2021-06-02 15:00:00
# 1  https://dpe7aw9wpk40m.cloudfront.net/3e55bb1e-...  2021-06-02 15:00:00
# ...

# %%
runs = runs[runs['base'] == 3]
runs = runs[runs['aika'] < 6]
runs = runs[runs['unix_time'] < 1630000000]

by_day = runs.groupby(by='unix_time').mean()
by_day['juoksu'].head()
# Out:
# unix_time
# 1622646000    5.119272
# 1622732400    5.121737
# 1622818800    5.058504
# 1622984400    5.208686
# 1622988000    5.121666
# Name: juoksu, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (50, 30))

y = runs['juoksu']
x = runs['unix_time']
plt.plot(by_day.juoksu, marker='X', label=id, color="g")
plt.scatter(x, y)
mean_line = plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)), color="r")
mean_line[0]
plt.show()

# %% [markdown]
# ## Johtuuko keskiarvon pudotus pudotuspelien alkamisesta?
